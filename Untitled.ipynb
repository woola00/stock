# %%
import os
import pandas as pd
import numpy as np
import FinanceDataReader as fdr

df = fdr.StockListing('KRX')

# %%
df.columns = [x.lower() for x in df.columns]
df = df[df.sector.notnull()]
print(len(df))
df
# Out:
# 2500
#       symbol  market    name                    sector  \
# 0     060310  KOSDAQ      3S                  전자부품 제조업
# 1     095570   KOSPI  AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI   AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ  APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ   AP시스템             특수 목적용 기계 제조업
# ...      ...     ...     ...                       ...
# 8008  189980  KOSDAQ  흥국에프엔비           비알코올음료 및 얼음 제조업
# 8009  000540   KOSPI    흥국화재                       보험업
# 8012  003280   KOSPI    흥아해운                    해상 운송업
# 8013  037440  KOSDAQ      희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 8016  238490  KOSDAQ      힘스             특수 목적용 기계 제조업
#
#                             industry listingdate settlemonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# ...

# %%
sector = dict(list(df.groupby('sector')))
print('count = :{}'.format(len(sector)))
med_sec = sector['의료용품 및 기타 의약 관련제품 제조업']
for ix, row in med_sec.iterrows() :
    code, name = row['symbol'], row['name']
    print(code, name)
# Out:
# count = :161
# 343090 HLB사이언스
# 138610 나이벡
# 142280 녹십자엠에스
# 233250 메디안디노스틱
# 059210 메타바이오메드
# 206640 바디텍메드
# 064550 바이오니아
# 100700 세운메디칼
# 253840 수젠텍
# 096530 씨젠
# 246720 아스타
# 260660 알리코제약
# 174900 앱클론
# 950130 엑세스바이오
# 153710 옵티팜
# 307280 원바이오젠
# 246960 이노테라피
# 086890 이수앱지스
# 216080 제테마
# 229000 젠큐릭스
# 228760 지노믹트리
# 352770 클리노믹스
# 340570 티앤엘
# 046210 파나진
# 214450 파마리서치
# 303360 프로테옴텍
# 241820 피씨엘
# 304840 피플바이오
# 042520 한스바이오메드
# 205470 휴마시스
